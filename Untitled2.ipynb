# %%
import params
params.init_args()
# Out:
# importing params
# RANDOM SEED: 1413474
# ORGANISM: Hpy
# 75
# Cannot mkdir ./output/
# ./Hpy/ratios.tsv.gz
# [-150, 10]
# [-250, 20]
# [6, 24]

# %%
import init
init.init('output/Hpy.pkl')
# Out:
# importing sequence
# importing scores
# importing weaved
# importing funcs
# importing meme
# importing Bicluster
# importing globals
# 2015-03-03 11:10:41.515700
# importing init
# 2015-03-03 09:50:58.328858
# DONE WITH INITIALIZATION!
# 2015-03-03 11:10:42.847610
# 1:19:44.518752 seconds since initialization

# %%
import funcs
kInd = funcs.clusters_w_func('flagell', glb.clusters, glb.anno, 3)
kInd
# Out:
# 8 3
#                                                      desc
# sysName
# HP0223                       ATP-dependent protease (sms)
# HP0237                   porphobilinogen deaminase (hemC)
# HP0238                      prolyl-tRNA synthetase (proS)
# HP0271                               hypothetical protein
# HP0353                    flagellar export protein (fliH)
# HP0399                        ribosomal protein S1 (rps1)
# HP0509                   glycolate oxidase subunit (glcD)
# HP0553                     conserved hypothetical protein
# HP0659                               hypothetical protein
# HP0840                                      flaA1 protein
# HP0886                   cysteinyl-tRNA synthetase (cysS)
# HP0955    prolipoprotein diacylglyceryl transferase (lgt)
# HP1030                                fliY protein (fliY)
# HP1035              flagellar biosynthesis protein (flhF)
# HP1039                               hypothetical protein
# HP1041              flagellar biosynthesis protein (flhA)
# HP1148         tRNA (guanine-N1)-methyltransferase (trmD)
# HP1372               rod shape-determining protein (mreC)
# HP1486   conserved hypothetical integral membrane protein
# HP1544                         toxR-activated gene (tagE)
# HP1545                 folylpolyglutamate synthase (folC)
# 25 3
#                                                       desc
# sysName
# HP0021                                hypothetical protein
# HP0142             A/G-specific adenine glycosylase (mutY)
# HP0319                      arginyl-tRNA synthetase (argS)
# HP0330                  ketol-acid reductoisomerase (ilvC)
# HP0331                      cell division inhibitor (minD)
# HP0333                       DNA processing chain A (dprA)
# HP0334                      conserved hypothetical protein
# HP0821                   excinuclease ABC subunit C (uvrC)
# HP0859     ADP-L-glycero-D-mannoheptose-6-epimerase (rfaD)
# HP0869     hydrogenase expression/formation protein (hypA)
# HP0870                               flagellar hook (flgE)
# HP1035               flagellar biosynthesis protein (flhF)
# HP1061    conserved hypothetical integral membrane protein
# HP1062   S-adenosylmethionine:tRNA ribosyltransferase-i...
# HP1076                                hypothetical protein
# HP1121    cytosine specific DNA methyltransferase (BSP6IM)
# HP1146                                hypothetical protein
# HP1155         transferase, peptidoglycan synthesis (murG)
# HP1230                                hypothetical protein
# HP1392              fibronectin/fibrinogen-binding protein
# HP1394                      conserved hypothetical protein
# HP1429   polysialic acid capsule expression protein (kpsF)
# HP1431   16S rRNA (adenosine-N6,N6-)-dimethyltransferas...
# HP1440                                hypothetical protein
# HP1558   flagellar basal-body rod protein (flgC) (proxi...
# 50 3
#                                                       desc
# sysName
# HP0112                                hypothetical protein
# HP0142             A/G-specific adenine glycosylase (mutY)
# HP0223                        ATP-dependent protease (sms)
# HP0237                    porphobilinogen deaminase (hemC)
# HP0238                       prolyl-tRNA synthetase (proS)
# HP0258    conserved hypothetical integral membrane protein
# HP0739         2-hydroxy-6-oxohepta-2,4-dienoate hydrolase
# HP0929                      geranyltranstransferase (ispA)
# HP0970     nickel-cobalt-cadmium resistance protein (nccB)
# HP1033                                hypothetical protein
# HP1034                          ATP-binding protein (ylxH)
# HP1035               flagellar biosynthesis protein (flhF)
# HP1090                        cell division protein (ftsK)
# HP1148          tRNA (guanine-N1)-methyltransferase (trmD)
# HP1430          conserved hypothetical ATP-binding protein
# HP1440                                hypothetical protein
# HP1443                      conserved hypothetical protein
# HP1444                                small protein (smpB)
# HP1494             UDP-MurNac-tripeptide synthetase (murE)
# HP1525                                hypothetical protein
# HP1556                        cell division protein (ftsI)
# HP1558   flagellar basal-body rod protein (flgC) (proxi...
# HP1559   flagellar basal-body rod protein (flgB) (proxi...
# array([ 8, 25, 50])

# %%
import globals as glb
import plot

# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')
plot.plot_motif_logo(glb.clusters[kInd[0]].meme_out,0)

# %%
plot.plot_motif_logo(glb.clusters[kInd[0]].meme_out,1)

# %%
plot.plot_stats()
# Out:
#          c0  g0  iter     m0  mem_used     n0  r0            time     v0  \
# 0  0.239474   0    97  0.480       467 -0.096   1 00:57:45.715312  0.196
# 0  0.239474   0    98  0.485       467 -0.097   1 00:58:47.688962  0.197
# 0  0.239474   0    99  0.490       467 -0.098   1 00:59:44.455841  0.198
# 0  0.239474   0   100  0.495       467 -0.099   1 01:00:43.644924  0.199
# 0  0.239474   0    99  0.490       467 -0.098   1 01:00:47.759435  0.198
#
#         ROWS       COLS     RESID  STRING_DENS  MEME_PVAL  CLUSTS_PER_ROW  \
# 0  22.000000  28.066667  0.541990     1.690303  -4.431282        2.782462
# 0  22.000000  28.226667  0.541554     1.690303  -4.431282        2.782462
# 0  22.000000  28.253333  0.541422     1.690303  -4.431282        2.782462
# 0  22.133333  28.613333  0.546417     1.686336  -4.416895        2.785235
# 0  22.133333  28.613333  0.546417     1.686336  -4.416895        2.785235
#
#    CLUSTS_PER_COL  N_MOVES  N_IMPROVEMENTS  N_CLUSTS_CHANGED_ROWS  \
# 0       36.929825      306              15                     68
# 0       37.140351      263               2                     67
# 0       37.175439      253               1                     61
# 0       37.649123      251               0                     64
# 0       37.649123        0               0                      0
#
#    N_CLUSTS_CHANGED_COLS
# 0                     11
# 0                     11
# 0                     12
# 0                     13
# 0                      0
