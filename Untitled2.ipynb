# %%
import params
params.init_args()
# Out:
# importing params
# RANDOM SEED: 1283008
# ORGANISM: Hpy
# 75
# OUTPUT: ./output/
# Cannot mkdir ./output/
# ./Hpy/ratios.tsv.gz
# [-150, 10]
# [-250, 20]
# [6, 24]

# %%
import init
init.init('output/Hpy.pkl')
# Out:
# importing sequence
# importing scores
# importing weaved
# importing funcs
# importing meme
# importing Bicluster
# importing globals
# 2015-03-03 11:36:51.476994
# importing init
# 2015-03-03 10:22:17.835042
# DONE WITH INITIALIZATION!
# 2015-03-03 11:36:52.506252
# 1:14:34.671210 seconds since initialization

# %%
import funcs
import globals as glb
kInd = funcs.clusters_w_func('flagell', glb.clusters, glb.anno, 3)
kInd
# Out:
# 27 3
#                                                       desc
# sysName
# HP0077            peptide chain release factor RF-1 (prfA)
# HP0223                        ATP-dependent protease (sms)
# HP0370                           biotin carboxylase (accC)
# HP0469                      conserved hypothetical protein
# HP0772           N-acetylmuramoyl-L-alanine amidase (amiA)
# HP0773                                hypothetical protein
# HP0814                 thiamin biosynthesis protein (thiF)
# HP0867              lipid A disaccharide synthetase (lpxB)
# HP0869     hydrogenase expression/formation protein (hypA)
# HP0870                               flagellar hook (flgE)
# HP0886                    cysteinyl-tRNA synthetase (cysS)
# HP1028                                hypothetical protein
# HP1030                                 fliY protein (fliY)
# HP1031               flagellar motor switch protein (fliM)
# HP1038                     3-dehydroquinase type II (aroQ)
# HP1061    conserved hypothetical integral membrane protein
# HP1062   S-adenosylmethionine:tRNA ribosyltransferase-i...
# HP1149                      conserved hypothetical protein
# HP1233                                hypothetical protein
# HP1373                rod shape-determining protein (mreB)
# HP1392              fibronectin/fibrinogen-binding protein
# HP1559   flagellar basal-body rod protein (flgB) (proxi...
# HP1567          conserved hypothetical GTP-binding protein
# 67 5
#                                                       desc
# sysName
# HP0142             A/G-specific adenine glycosylase (mutY)
# HP0216                      conserved hypothetical protein
# HP0223                        ATP-dependent protease (sms)
# HP0238                       prolyl-tRNA synthetase (proS)
# HP0333                       DNA processing chain A (dprA)
# HP0508                                hypothetical protein
# HP0509                    glycolate oxidase subunit (glcD)
# HP0510                dihydrodipicolinate reductase (dapB)
# HP0656                      conserved hypothetical protein
# HP0659                                hypothetical protein
# HP0753                            flagellar protein (fliS)
# HP0839                   outer membrane protein P1 (ompP1)
# HP0840                                       flaA1 protein
# HP1041               flagellar biosynthesis protein (flhA)
# HP1044    conserved hypothetical integral membrane protein
# HP1090                        cell division protein (ftsK)
# HP1119   flagellar hook-associated protein 1 (HAP1) (flgK)
# HP1558   flagellar basal-body rod protein (flgC) (proxi...
# HP1559   flagellar basal-body rod protein (flgB) (proxi...
# 17 7
#                                                       desc
# sysName
# HP0114                                hypothetical protein
# HP0115                                  flagellin B (flaB)
# HP0295                           flagellin B homolog (fla)
# HP0396                      conserved hypothetical protein
# HP0839                   outer membrane protein P1 (ompP1)
# HP0840                                       flaA1 protein
# HP0841          pantothenate metabolism flavoprotein (dfp)
# HP0858                         ADP-heptose synthase (rfaE)
# HP0859     ADP-L-glycero-D-mannoheptose-6-epimerase (rfaD)
# HP0861                                hypothetical protein
# HP0867              lipid A disaccharide synthetase (lpxB)
# HP0869     hydrogenase expression/formation protein (hypA)
# HP0870                               flagellar hook (flgE)
# HP1029                                hypothetical protein
# HP1030                                 fliY protein (fliY)
# HP1031               flagellar motor switch protein (fliM)
# HP1119   flagellar hook-associated protein 1 (HAP1) (flgK)
# HP1154                                hypothetical protein
# HP1155         transferase, peptidoglycan synthesis (murG)
# HP1429   polysialic acid capsule expression protein (kpsF)
# HP1558   flagellar basal-body rod protein (flgC) (proxi...
# HP1559   flagellar basal-body rod protein (flgB) (proxi...
# array([27, 67, 17])

# %%
import plot

# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')
plot.plot_motif_logo(glb.clusters[kInd[2]].meme_out,0)
# Out:
# importing plot

# %%
plot.plot_motif_logo(glb.clusters[kInd[2]].meme_out,1)

# %%
plot.plot_stats()
